# %%
import numpy
# Out:
# NameError: undefined local variable or method `numpy' for main:Object
# (pry):2:in `<main>'
# /Users/pitosalas/.rbenv/versions/2.5.0/lib/ruby/gems/2.5.0/gems/pry-0.11.3/lib/pry/pry_instance.rb:355:in `eval'
# /Users/pitosalas/.rbenv/versions/2.5.0/lib/ruby/gems/2.5.0/gems/pry-0.11.3/lib/pry/pry_instance.rb:355:in `evaluate_ruby'
# /Users/pitosalas/.rbenv/versions/2.5.0/lib/ruby/gems/2.5.0/gems/pry-0.11.3/lib/pry/pry_instance.rb:323:in `handle_line'
# /Users/pitosalas/.rbenv/versions/2.5.0/lib/ruby/gems/2.5.0/gems/pry-0.11.3/lib/pry/pry_instance.rb:243:in `block (2 levels) in eval'
# /Users/pitosalas/.rbenv/versions/2.5.0/lib/ruby/gems/2.5.0/gems/pry-0.11.3/lib/pry/pry_instance.rb:242:in `catch'
# /Users/pitosalas/.rbenv/versions/2.5.0/lib/ruby/gems/2.5.0/gems/pry-0.11.3/lib/pry/pry_instance.rb:242:in `block in eval'
# /Users/pitosalas/.rbenv/versions/2.5.0/lib/ruby/gems/2.5.0/gems/pry-0.11.3/lib/pry/pry_instance.rb:241:in `catch'
# ...
